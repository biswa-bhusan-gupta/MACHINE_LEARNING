# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,3],color="Red",linestyle="dashed",marker="o",label="Hello World")
plt.legend()
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot([1,2,3],[5,4,3])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.pie([6,4,2])
plt.show()

# %%
plt.bar([1,5,9],[5,6,8],label="Movies",color="Yellow")
plt.show()

# %%
# %matplotlib tk
import matplotlib.pyplot as plt
plt.plot([1,2,3],[5,4,3])
plt.show()
# Out:
# ...
# <img src="data:image/png;base64,..." width="432">
